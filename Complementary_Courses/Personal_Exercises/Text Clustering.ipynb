# %% [markdown]
# ## Data Preparation

# %%
import os
import pickle
from pprint import pprint
from os.path import join as JP

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

from utils.nlp_utils import preproces
from utils.general import parse_yaml, ensure_directories

from scripts.catalog import (
    Catalog, Document, Corpus,
    load_catalog, load_corpus)

from utils.datahandling import (
    filter_dict_by_keys, 
    filter_dict_by_vals,
    filter_df_mean_thres)


# CONFIG 
# ------

config = parse_yaml('config.yaml')
paths = config['paths']
ensure_directories(paths)

# %%
catalog = Catalog()
corpus = load_corpus(path=paths['catalog'], name='sample_data')
catalog.load_corpus(corpus=corpus)
# catalog.save(path=paths['catalog'],name='test1_clean')

OF_INTEREST = ['AU', 'CA','US']

# Filter down the catalog
filters = dict(
    topic = ['isocyanate'],
    country = OF_INTEREST,
    raw_text_len = 5000)

catalog_sample = catalog.filter_catalog(filters)
print('Catalog recuded from {} to {}'.format(
    len(catalog.documents), len(catalog_sample.documents)))
# Out:
# Catalog recuded from 3013 to 730

# %%
# SPLIT CATALOG INTO THE TWO CATEGORIES
# -------------------------------------

filters = dict(label='relevant')
pos_catalog = catalog_sample.filter_catalog(filters)

filters = dict(label='irrelevant')
neg_catalog = catalog_sample.filter_catalog(filters)

print('Positive documents: ',len(pos_catalog.documents))
print('Negative documents: ',len(neg_catalog.documents))
# Out:
# Positive documents:  53
# Negative documents:  677

# %%
catalog = pos_catalog

# %% [markdown]
# ## Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS

# %%
document = catalog.documents[0]
document.clean_text[:50]
# Out:
# 'Application published. OKAZOE, Takashi;Nagasaki, Y'

# %%
for d,doc in enumerate(catalog.documents[:3]):
    print('[INFO]: Parsing doc ',d)
    catalog.documents[d].sp_doc = nlp(doc.clean_text)
catalog.save(path=paths['catalog'],name='sample_data_spacy')
# Out:
# [INFO]: Parsing doc  0
# [INFO]: Parsing doc  1
# [INFO]: Parsing doc  2

# %%
# catalog.documents[0].sp_doc = nlp(catalog.documents[0].clean_text)
list(catalog.documents[1].sp_doc.noun_chunks)
# Out:
# [Application,
#  Zeeuw,
#  Arend-Jan;Bent,
#  Mark Geoffrey,
#  Huntsman International,
#  INTERNATIONAL,
#  HUNTSMAN INTERNATIONAL,
#  Chemical Installation,
#  the present invention,
#  a chemical installation,
#  The chemical installation,
#  A first unit,
#  a first aqueous waste stream comprising nitrobenzene,
#  At least a second unit,
#  a second aqueous waste stream comprising aniline,
#  The chemical installation,
#  an aniline cleaning apparatus,
#  nitrobenzene,
#  aniline,
#  a stripping column,
#  an aqueous stream,
#  The first and second aqueous waste stream,
#  the stripping column,
#  aniline,
#  nitrobenzene,
#  the aqueous waste stream,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline cleaning apparatus,
#  CROSS-REFERENCE,
#  RELATED APPLICATIONS,
#  application,
#  U.S. patent application Ser,
#  which,
#  the National Phase,
#  International Application,
#  May,
#  which,
#  the U.S.,
#  which,
#  priority,
#  The noted applications,
#  reference,
#  0002]The present invention,
#  a chemical installation,
#  DADPM,
#  an integrated chemical installation,
#  a nitrobenzene production unit,
#  benzene,
#  nitrobenzene,
#  an aniline production unit,
#  nitrobenzene,
#  aniline,
#  a DADPM,
#  production unit,
#  the aniline,
#  DADPM,
#  an MDI unit,
#  the DADPM,
#  MDI,
#  diphenylmethane diisocyanate,
#  present invention,
#  a production process,
#  DADPM,
#  MDI,
#  installations,
#  DADPM,
#  MDA,
#  the art,
#  Diaminodiphenylmethane,
#  general methylene-bridged polyphenyl polyamines,
#  aniline,
#  aniline derivatives,
#  them,
#  formaldehyde,
#  the presence,
#  a solution,
#  a strong acid,
#  example,
#  Literary sources,
#  which,
#  this type,
#  synthesis,
#  J. Am,
#  Chem,
#  Soc,
#  57, 888, 1975; Chem,
#  Tech.,
#  November,
#  Kirk Othmer,
#  Vol.. II,
#  3rd Edition,
#  Some other catalysts,
#  diatomaceous earth,
#  clay,
#  zeolites,
#  the conversion,
#  aniline,
#  formaldehyde,
#  DADPM,
#  the conversion,
#  aniline,
#  formaldehyde,
#  formalin,
#  the DADPM,
#  a reactor,
#  effluent stream comprising,
#  DADPM,
#  aniline,
#  acid,
#  catalyst,
#  impurities,
#  the supply streams,
#  side reactions,
#  typically hydrochloric acid,
#  catalyst,
#  this acid,
#  the reaction,
#  a base,
#  typically caustic soda,
#  the effluent stream,
#  a salty stream,
#  0006]The DADPM,
#  the effluent stream,
#  means,
#  a phase separator,
#  The aqueous effluent,
#  this first phase separator,
#  brine,
#  aniline,
#  the traces,
#  DADPM,
#  this aqueous effluent,
#  The resulting streams,
#  an aqueous phase,
#  water,
#  aniline,
#  an organic phase,
#  DADPM,
#  aniline,
#  as much aniline,
#  this aqueous stream,
#  an aqueous, optionally salty, stream,
#  biological waste stream treatment installations,
#  the aniline,
#  the aqueous stream,
#  a stripping column,
#  aniline stripper,
#  amine brine stripper,
#  amine water stripper,
#  [0008]The aniline,
#  the DADPM production unit,
#  a bulk chemical,
#  Aniline,
#  itself,
#  an aniline production unit,
#  the DADPM production unit,
#  The conversion,
#  nitrobenzene,
#  aniline,
#  an aqueous waste stream,
#  water,
#  which,
#  aniline,
#  a biochemical treatment unit,
#  the aniline,
#  DADPM production,
#  nitrobenzene,
#  the aniline production unit,
#  an aniline cleaning apparatus,
#  nitrobenzene,
#  the aniline,
#  example,
#  a process,
#  crude aniline,
#  US2007/0203364A1,
#  0011]The nitrobenzene,
#  the aniline production unit,
#  a bulk chemical,
#  This nitrobenzene production unit,
#  nitrobenzene,
#  an aqueous waste stream,
#  which,
#  nitrobenzene,
#  this waste stream,
#  nitrobenzene,
#  a biochemical treatment unit,
#  An example,
#  a process,
#  nitrated aromatic hydrocarbons,
#  EP1484312A1,
#  a method,
#  crude nitrobenzene,
#  all three units,
#  the other, i.e. the nitrobenzene production unit,
#  the aniline production unit,
#  the DADPM production unit,
#  an MDI production unit,
#  the DADPM,
#  MDI,
#  it,
#  some economical and technical benefit,
#  all waste streams,
#  the same biological waste water treating unit,
#  Large scale benefits,
#  this biological waste water treatment unit,
#  only one unit,
#  the disadvantage,
#  the organic compound,
#  either aniline,
#  nitrobenzene,
#  each individual waste stream,
#  an aqueous streams,
#  the biological waste water treatment unit,
#  it,
#  a way,
#  the aqueous waste streams,
#  removal,
#  the organic components,
#  it,
#  the organic compounds,
#  a way,
#  one aqueous stream,
#  biological treatable waste water,
#  the meantime,
#  the aniline,
#  the production cycle,
#  production,
#  DADPM,
#  objective,
#  a chemical installation,
#  the present invention,
#  a first aspect,
#  the present invention,
#  a chemical installation,
#  The chemical installation,
#  [0018]A first unit,
#  a first aqueous waste stream comprising nitrobenzene,
#  [0019]At least a second unit,
#  a second aqueous waste stream comprising aniline,
#  0020]The chemical installation,
#  an aniline cleaning apparatus,
#  nitrobenzene,
#  aniline,
#  a stripping column,
#  an aqueous stream,
#  The first and second aqueous waste stream,
#  the stripping column,
#  aniline,
#  nitrobenzene,
#  the aqueous waste stream,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline cleaning apparatus,
#  some embodiments,
#  the chemical installation,
#  0022]the first unit,
#  a nitrobenzene production unit,
#  benzene,
#  nitrobenzene,
#  a nitrobenzene stream,
#  the first aqueous waste stream,
#  comprising nitrobenzene,
#  0023]the second unit,
#  an aniline production unit,
#  the nitrobenzene,
#  the nitrobenzene stream,
#  aniline,
#  an aniline stream,
#  the second aqueous waste stream,
#  a first part,
#  the second aqueous waste stream comprising aniline,
#  0024]The installation,
#  a DADPM production unit,
#  the aniline,
#  the aniline stream,
#  DADPM,
#  a second part,
#  the second aqueous waste stream comprising aniline,
#  [0025]The first aqueous waste stream comprising nitrobenzene,
#  the aqueous effluent,
#  a phase separator,
#  the produced nitrobenzene,
#  the typically acid water,
#  This water,
#  the nitrobenzene production unit,
#  the acids,
#  the process,
#  sulphuric acid,
#  nitric acid,
#  reaction water,
#  the conversion,
#  the first aqueous waste stream,
#  the aqueous phase,
#  the phase separator,
#  the acids,
#  the nitrobenzene production,
#  water,
#  some nitrobenzene,
#  typically less than 0.5 wt %,
#  0.3 wt %,
#  some nitrophenols,
#  nitrates,
#  nitrites,
#  ppm level,
#  This aqueous phase,
#  a base,
#  , preferably caustic soda,
#  the aqueous stream,
#  salts,
#  optionally sodium salts,
#  sulphuric acid and nitric acid,
#  0026]The second aqueous waste stream,
#  different units,
#  each unit,
#  part,
#  the second aqueous waste stream,
#  0027]The first part,
#  this second aqueous waste stream comprising aniline,
#  the effluent,
#  the aniline reactor,
#  Nitrobenzene,
#  hydrogen,
#  outlet stream,
#  the reactor,
#  then phase,
#  gravity,
#  The aqueous phase,
#  this phase separation,
#  water,
#  typically 95.95 wt %,
#  some aniline,
#  typically about 4.04 wt %,
#  second part,
#  this second aqueous waste stream comprising aniline,
#  the aqueous effluent,
#  a phase separator,
#  organic phase,
#  the aqueous stream,
#  DADPM production,
#  the water,
#  brine,
#  this aniline,
#  The second part,
#  this second aqueous waste stream,
#  water (typically about 81.08 wt %,
#  the salt,
#  the acid catalyst,
#  typically 16.55 wt %,
#  sodium chloride,
#  aniline,
#  typically about 1.71 wt %,
#  ppm-levels,
#  0030]The parts,
#  the second aqueous waste stream,
#  it,
#  the stripping column,
#  the alternative,
#  the stripping column,
#  individual streams,
#  the present invention,
#  any number,
#  aqueous waste streams,
#  nitrobenzene,
#  aniline,
#  as the nitrobenzene and/or aniline levels,
#  the water/brine,
#  the solubility limit,
#  the case,
#  you,
#  a phase separation,
#  the chemical installation,
#  an aniline production unit,
#  which,
#  a reactor,
#  said nitrobenzene,
#  aniline,
#  the aniline cleaning apparatus,
#  nitrobenzene,
#  the provided aniline,
#  the effluent,
#  this reactor,
#  This aniline cleaning apparatus,
#  aniline polisher,
#  aniline,
#  nitrobenzene,
#  an aniline cleaning apparatus,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline,
#  the reactor,
#  the stripped aniline,
#  nitrobenzene,
#  the nitrobenzene,
#  the reactor,
#  which,
#  its turn,
#  a part,
#  the stripped nitrobenzene,
#  aniline,
#  the stripped aniline,
#  the aniline cleaning apparatus,
#  some embodiments,
#  the present invention,
#  the aniline production unit,
#  a reactor,
#  the nitrobenzene,
#  aniline,
#  the aniline cleaning apparatus,
#  nitrobenzene,
#  the provided aniline,
#  the effluent,
#  the reactor,
#  the stripped aniline,
#  nitrobenzene,
#  reactor,
#  nitrobenzene,
#  aniline,
#  some embodiments,
#  the present invention,
#  the aniline production unit,
#  a reactor,
#  the nitrobenzene,
#  aniline,
#  the aniline cleaning apparatus,
#  nitrobenzene,
#  the provided aniline,
#  the effluent,
#  said reactor,
#  the stripped aniline,
#  nitrobenzene,
#  the effluent,
#  this reactor,
#  the aniline cleaning apparatus,
#  the advantage,
#  the nitrobenzene,
#  the DADPM production,
#  the DADPM production unit,
#  this aniline cleaning apparatus,
#  0037]The aniline stripper,
#  the aqueous waste stream,
#  the invention,
#  the first and second waste stream,
#  the stripped aniline,
#  nitrobenzene,
#  aniline cleaning apparatus,
#  an effluent,
#  which,
#  an aqueous waste stream,
#  treatment,
#  a biological waste stream treating unit,
#  [0038]The stream,
#  stripped aniline,
#  nitrobenzene,
#  water,
#  Recycling,
#  water,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline cleaning apparatus,
#  the reactor,
#  conversion,
#  nitrobenzene,
#  aniline,
#  a major issue,
#  the nitrobenzene stream,
#  water,
#  the conversion,
#  nitrobenzene,
#  aniline generates water,
#  stripping column,
#  a reboiler,
#  live steam injection,
#  Heating,
#  the reboiler,
#  the stripping column,
#  high or low pressure steam,
#  which,
#  total,
#  the nitrobenzene production unit,
#  the aniline production unit,
#  the DADPM production unit,
#  0040]The stripping column,
#  a pressure,
#  atmospheric,
#  a range,
#  0.95 bara,
#  1.2 bara,
#  such conditions,
#  the temperature,
#  the stripping column,
#  a range,
#  98 deg C.,
#  110 deg C.,
#  The temperatures,
#  the bottom,
#  the column,
#  the strength,
#  brine,
#  the effluent,
#  an alternative,
#  the stripping column,
#  pressures,
#  atmospheric pressure,
#  a pressure,
#  (3 bara,
#  11 bara,
#  7 bara,
#  The temperature,
#  the stripping column,
#  a range 134 deg C.,
#  190 deg C.,
#  the range,
#  160 deg C.,
#  170 deg C,
#  aniline,
#  nitrobenzene,
#  water,
#  the stripping column,
#  a vapor phase,
#  The vapor comprising aniline,
#  nitrobenzene,
#  water vapor,
#  the stripping column,
#  This condensing,
#  a methanol fractionator column,
#  which,
#  the DADPM production unit,
#  0043]The condensate,
#  an aqueous phase,
#  water,
#  the stripped nitrobenzene,
#  an organic phase,
#  the stripped aniline,
#  nitrobenzene,
#  This separation,
#  a phase separation apparatus,
#  the aqueous phase,
#  the light phase,
#  the organic phase,
#  the heavy phase,
#  only this organic phase,
#  the aniline cleaning apparatus,
#  the aqueous phase,
#  the stripping column,
#  a further feed,
#  the three waste streams,
#  some embodiments,
#  the present invention,
#  the chemical installation,
#  a condenser,
#  the stripped aniline,
#  nitrobenzene,
#  water,
#  optionally a phase separator,
#  the condensed aniline,
#  nitrobenzene,
#  water,
#  an aqueous phase,
#  water,
#  the stripped nitrobenzene,
#  the stripped aniline,
#  nitrobenzene,
#  some water,
#  some embodiments,
#  the present invention,
#  the chemical installation,
#  means,
#  the aqueous phase,
#  the stripping column,
#  the condensate,
#  the top,
#  the stripping column,
#  it,
#  droplets,
#  optionally solids,
#  the vapor phase,
#  which phase,
#  the stripping column,
#  a trayed section,
#  a structured packing section,
#  some heat,
#  the stripped aniline,
#  nitrobenzene,
#  its vapor phase,
#  water,
#  the stripping column,
#  This heat,
#  steam,
#  atmospheric pressure,
#  9 bara,
#  0049]The nitrobenzene production unit,
#  an aqueous waste stream comprising nitrobenzene,
#  the first waste stream,
#  which,
#  These components,
#  contact,
#  an amine,
#  an acidic environment,
#  tar,
#  which,
#  the stripping column,
#  It,
#  the waste streams,
#  the stripping column,
#  the risk,
#  tar,
#  nitrites,
#  the first waste stream,
#  the aniline,
#  some embodiments,
#  the present invention,
#  the stripping column,
#  n theoretical trays,
#  Al,
#  An,
#  Al,
#  the top tray,
#  the bottom tray,
#  The second waste stream,
#  the stripping column,
#  theoretical tray Ax,
#  The first waste stream,
#  the stripping column,
#  a theoretical tray A[y,
#  [y,
#  the integer,
#  y,
#  y,
#  the equation,
#  y,
#  the equation,
#  It,
#  y,
#  the equation,
#  waste water,
#  nitrobenzene,
#  the stripper,
#  a significantly large distance,
#  the entry,
#  the waste water comprising aniline,
#  0053]Nitrobenzene,
#  water,
#  the nitrobenzene comprising waste stream,
#  waste stream,
#  streams,
#  the advantage,
#  the aniline,
#  the water,
#  the nitrobenzene comprising waste stream,
#  an efficient stripping,
#  the aniline,
#  the further dilution,
#  the nitrobenzene,
#  the water,
#  waste streams,
#  a position,
#  the nitrobenzene comprising waste stream feed,
#  the stripping efficiency,
#  the nitrobenzene,
#  the aqueous stream,
#  this distinct feeding,
#  the two waste streams,
#  the overall amount,
#  organic components,
#  the resulting stream,
#  the bio treatment,
#  all other factors,
#  it,
#  the two aqueous streams,
#  a common stripper,
#  the streams' feed positions,
#  the column,
#  a more economical use,
#  energy,
#  the stripping columns,
#  the amount,
#  organics,
#  volume bio-treatable waste stream,
#  the range,
#  200 to 500 ppb,
#  the same amount,
#  material,
#  equal volumes,
#  first and second aqueous streams,
#  all cases,
#  it,
#  the steam,
#  hence energy,
#  one stripping column,
#  all packing material,
#  both first and second aqueous streams,
#  the steam,
#  two stripping columns,
#  the aniline,
#  a same volume,
#  the second aqueous stream,
#  the nitrobenzene,
#  the same volume,
#  first aqueous stream,
#  the packing material,
#  the two stripping columns,
#  the amount,
#  organics,
#  volume bio-treatable waste stream,
#  the range,
#  200 to 500 ppb,
#  an equal amount,
#  steam,
#  equal volumes,
#  first and second aqueous streams,
#  all cases,
#  it,
#  the packing material,
#  one stripping column,
#  both first and second aqueous streams,
#  the total height,
#  material,
#  two stripping columns,
#  the aniline,
#  a same volume,
#  the second aqueous stream,
#  the nitrobenzene,
#  the same volume,
#  first aqueous stream,
#  Hence a reduction,
#  either installation cost,
#  height,
#  (volume,
#  material,
#  a reduction,
#  energy consumption,
#  about 15%,
#  the two aqueous streams,
#  a common stripper,
#  the two aqueous streams,
#  different positions,
#  the stripping column,
#  the advantage,
#  the amount,
#  material,
#  theoretical trays,
#  the stripping column,
#  tolerable level,
#  combined feeds,
#  the two aqueous streams,
#  which,
#  the same purity,
#  same energy consumption,
#  the packing height,
#  number,
#  theoretical trays,
#  a factor,
#  0058]In order,
#  the risk,
#  tar,
#  reaction,
#  nitrites,
#  aniline,
#  the stripping column,
#  the first waste stream comprising nitrobenzene,
#  a basic component,
#  preferably caustic soda,
#  a second aspect,
#  the present invention,
#  an installation,
#  the first aspect,
#  the present invention,
#  the production process,
#  DADPM,
#  a second aspect,
#  the present invention,
#  a method,
#  DADPM,
#  benzene,
#  nitrobenzene,
#  a nitrobenzene stream,
#  a first aqueous waste stream comprising nitrobenzene,
#  the nitrobenzene,
#  nitrobenzene stream,
#  aniline,
#  an aniline stream,
#  a first part,
#  a second aqueous waste stream comprising aniline,
#  nitrobenzene,
#  the aniline,
#  the aniline,
#  aniline stream,
#  DADPM,
#  the aniline,
#  the aniline stream,
#  DADPM,
#  a second part,
#  aniline,
#  nitrobenzene,
#  the first and second aqueous waste stream,
#  means,
#  a stripping column,
#  the stripped aniline,
#  nitrobenzene,
#  an aniline cleaning apparatus,
#  nitrobenzene stream,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline cleaning apparatus,
#  some embodiments,
#  the present invention,
#  the aniline production unit,
#  a reactor,
#  the nitrobenzene,
#  aniline,
#  the nitrobenzene,
#  the nitrobenzene stream,
#  aniline comprises,
#  the stripped aniline,
#  nitrobenzene,
#  the reactor,
#  the nitrobenzene,
#  aniline,
#  [0070]converting nitrobenzene,
#  aniline,
#  a reactor,
#  nitrobenzene,
#  the provided aniline,
#  an aniline cleaning apparatus,
#  some embodiments,
#  the present invention,
#  the aniline production unit,
#  a reactor,
#  the nitrobenzene,
#  aniline,
#  the nitrobenzene,
#  the nitrobenzene stream,
#  aniline comprises,
#  [0073]converting nitrobenzene,
#  aniline,
#  the reactor,
#  the stripped aniline,
#  nitrobenzene,
#  the aniline,
#  reactor effluent,
#  nitrobenzene,
#  the aniline,
#  an aniline cleaning apparatus,
#  some embodiments,
#  the present invention,
#  the stripping column,
#  n theoretical trays,
#  Al,
#  An,
#  Al,
#  the top tray,
#  the bottom tray,
#  the second waste stream,
#  the stripping column,
#  theoretical tray Ax,
#  the first waste stream,
#  the stripping column,
#  a theoretical tray A[y,
#  [y,
#  the integer,
#  y,
#  y,
#  the equation,
#  <y<0.85*(n+1)+0.15*x,
#  some embodiments,
#  the present invention,
#  the stripping column,
#  the stripped aniline,
#  nitrobenzene,
#  water,
#  a vapor,
#  method,
#  the stripped aniline,
#  nitrobenzene,
#  water,
#  the condensed aniline,
#  nitrobenzene,
#  water,
#  an aqueous phase,
#  water,
#  the stripped nitrobenzene,
#  an organic phase,
#  the stripped aniline,
#  nitrobenzene,
#  some water,
#  some embodiments,
#  the present invention,
#  the aqueous phase,
#  the stripping column,
#  a further feed,
#  the first and second waste streams,
#  0079]The independent and dependent claims,
#  particular and preferred features,
#  the invention,
#  Features,
#  the dependent claims,
#  features,
#  the independent or other dependent claims,
#  the present invention,
#  the following detailed description,
#  conjunction,
#  the accompanying drawings,
#  which,
#  way,
#  example,
#  the principles,
#  the invention,
#  This description,
#  the sake,
#  example,
#  the scope,
#  the invention,
#  The reference figures,
#  refer,
#  the attached drawings,
#  a schematic view,
#  chemical installation,
#  the present invention,
#  a schematic view,
#  the stripping column,
#  a method,
#  installation,
#  the present invention,
#  0083]The same reference signs,
#  the same, similar or analogous elements,
#  the different figures,
#  present invention,
#  respect,
#  particular embodiments,
#  the term "comprising,
#  the claims,
#  the means,
#  it,
#  other elements,
#  steps,
#  It,
#  the presence,
#  the stated features,
#  steps,
#  components,
#  the presence,
#  addition,
#  one or more other features,
#  steps,
#  components,
#  groups,
#  the scope,
#  the expression,
#  a device comprising,
#  B,
#  devices,
#  components,
#  A,
#  B.,
#  It,
#  respect,
#  the present invention,
#  the only relevant components,
#  the device,
#  A,
#  B,
#  this specification,
#  one embodiment,
#  "an embodiment,
#  Such references,
#  a particular feature,
#  relation,
#  the embodiment,
#  at least one embodiment,
#  the present invention,
#  appearances,
#  the phrases,
#  one embodiment,
#  an embodiment,
#  various places,
#  this specification,
#  the same embodiment,
#  they,
#  the particular features,
#  characteristics,
#  any suitable manner,
#  one or more embodiments,
#  ordinary skill,
#  the art,
#  terms,
#  the understanding,
#  the invention,
#  0088]The term DADPM,
#  "methylene-bridged polyphenyl polyamines,
#  diaminodiphenylmethane isomers,
#  higher homologues,
#  polymers,
#  [0089]The term "bara,
#  "bar absolute,
#  the absolute pressure,
#  % w,
#  the weight percentage,
#  the component,
#  reference,
#  ...]

# %% [markdown]
# ## TFIDF

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(
    min_df=.1,
    max_df=.7,
    norm='l2',
    use_idf=True,
    smooth_idf=True,
    max_features=3000,
    ngram_range=(1,3),
    lowercase=True,
    stop_words=stopwords.words('english'))
